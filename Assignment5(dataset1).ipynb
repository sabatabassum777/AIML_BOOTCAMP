# %%
#creating a DataFrame
import pandas as pd
#creating an empty dataframe
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#intialize list elements
data=[0.2,0.4,0.6,0.8]
df=pd.DataFrame(data,columns=['bacteria_size'])
df['max_growth']=[3.4,3.8,4.2,4.6]
df
# Out:
#    bacteria_size  max_growth
# 0            0.2         3.4
# 1            0.4         3.8
# 2            0.6         4.2
# 3            0.8         4.6

# %%
#splitting the data
x_train=df.iloc[:3,:-1]
y_train=df.iloc[:3,-1:]
x_test=df.iloc[3:,:-1]
y_test=df.iloc[3:,-1:]

# %%
x_train
# Out:
#    bacteria_size
# 0            0.2
# 1            0.4
# 2            0.6

# %%
y_train
# Out:
#    max_growth
# 0         3.4
# 1         3.8
# 2         4.2

# %%
x_test
# Out:
#    bacteria_size
# 3            0.8

# %%
y_test
# Out:
#    max_growth
# 3         4.6

# %%
import sympy as sym
from sympy import *

# %%
#step1:Initialize model parameters
mi = 1                                                                            
ci = -1
n = 0.1
epochs = 50
iter = 1
ns = len(x_train)

# Step2: Start iteration
for iter in range(1,epochs+1):
  print("Iteration : {}".format(iter))
  print('++++++++++++++++++++++++++++')
  #step3: track samples
  for sample in range(0,ns):
    xa = x_train['bacteria_size'][sample] #0.2
    ya = y_train['max_growth'][sample] #3.4
    print("-->sample {}".format(sample+1)+"x={}".format(xa)+"y={}".format(ya))

    #step 4:Calculate the Gradient
    E = (0.5)*(y-m*x-c)**2 # Gradient Function
    x = sym.Symbol('x')
    y = sym.Symbol('y')
    m = sym.Symbol('m')
    c = sym.Symbol('c')

    deltaE_m = sym.diff(E,m)
    deltaE_c = sym.diff(E,c)

    #substituting values
    deltaE_m=deltaE_m.subs(m,mi)
    deltaE_m=deltaE_m.subs(c,ci)
    deltaE_m=deltaE_m.subs(x,xa)
    deltaE_m=deltaE_m.subs(y,ya)

    deltaE_c=deltaE_c.subs(m,mi)
    deltaE_c=deltaE_c.subs(c,ci)
    deltaE_c=deltaE_c.subs(x,xa)
    deltaE_c=deltaE_c.subs(y,ya)

    print('deltaE_m:',deltaE_m)
    print('deltaE_c',deltaE_c)

    #Step5: Calculate step length
    del_m=-n*deltaE_m
    del_c=-n*deltaE_c

    #step6:Updating model parameters
    mi=mi+del_m
    ci=ci+del_c
    print("m:{}".format(mi))
    print("c:{}".format(ci))

print('++++++++++++++++++++++++++++++++++++++')
print('Optimal Values:')
print("m:{}".format(mi))
print("c:{}".format(ci))
# Out:
# Iteration : 1
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.840000000000000
# deltaE_c -4.20000000000000
# m:1.08400000000000
# c:-0.580000000000000
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.57856000000000
# deltaE_c -3.94640000000000
# m:1.24185600000000
# c:-0.185360000000000
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.18414784000000
# deltaE_c -3.64024640000000
# m:1.46027078400000
# c:0.178664640000000
# Iteration : 2
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.585856240640000
# deltaE_c -2.92928120320000
# m:1.51885640806400
# c:0.471592760320000
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.08834587058176
# deltaE_c -2.72086467645440
# m:1.62769099512218
# c:0.743679227965440
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.48782370497675
# deltaE_c -2.47970617496125
# m:1.77647336561985
# c:0.991649845461566
# Iteration : 3
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.410611096282893
# deltaE_c -2.05305548141446
# m:1.81753447524814
# c:1.19695539360301
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.750412326519093
# deltaE_c -1.87603081629773
# m:1.89257570790005
# c:1.38455847523279
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.00793766001631
# deltaE_c -1.67989610002719
# m:1.99336947390168
# c:1.55254808523550
# Iteration : 4
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.289755603996832
# deltaE_c -1.44877801998416
# m:2.02234503430136
# c:1.69742588723392
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.517454439618214
# deltaE_c -1.29363609904553
# m:2.07409047826319
# c:1.82678949713847
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.677253729542170
# deltaE_c -1.12875621590362
# m:2.14181585121740
# c:1.93966511872883
# Iteration : 5
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.206394342205537
# deltaE_c -1.03197171102768
# m:2.16245528543796
# c:2.04286228983160
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.356862238397286
# deltaE_c -0.892155595993214
# m:2.19814150927769
# c:2.13207784943092
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.449422347001479
# deltaE_c -0.749037245002465
# m:2.24308374397783
# c:2.20698157393117
# Iteration : 6
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.148880335454653
# deltaE_c -0.744401677273262
# m:2.25797177752330
# c:2.28142174165850
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.246155818932873
# deltaE_c -0.615389547332184
# m:2.28258735941659
# c:2.34296069639172
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.292492132775000
# deltaE_c -0.487486887958333
# m:2.31183657269409
# c:2.39170938518755
# Iteration : 7
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.109184660054727
# deltaE_c -0.545923300273634
# m:2.32275503869956
# c:2.44630171521491
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.169838507722106
# deltaE_c -0.424596269305265
# m:2.33973888947177
# c:2.48876134214544
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.184437194502900
# deltaE_c -0.307395324171500
# m:2.35818260892206
# c:2.51950087456259
# Iteration : 8
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0817725207305999
# deltaE_c -0.408862603652999
# m:2.36635986099512
# c:2.56038713492789
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.117227568269625
# deltaE_c -0.293068920674064
# m:2.37808261782208
# c:2.58969402699530
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.110073841386873
# deltaE_c -0.183456402311456
# m:2.38909000196077
# c:2.60803966722644
# Iteration : 9
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0628284664762812
# deltaE_c -0.314142332381405
# m:2.39537284860840
# c:2.63945390046458
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0809587840368240
# deltaE_c -0.202396960092060
# m:2.40346872701208
# c:2.65969359647379
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0589351003913796
# deltaE_c -0.0982251673189660
# m:2.40936223705122
# c:2.66951611320568
# Iteration : 10
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0497222878768145
# deltaE_c -0.248611439384073
# m:2.41433446583890
# c:2.69437725714409
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0559555826081397
# deltaE_c -0.139888956520349
# m:2.41993002409971
# c:2.70836615279613
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0238054996464276
# deltaE_c -0.0396758327440461
# m:2.42231057406436
# c:2.71233373607053
# Iteration : 11
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0406408298233196
# deltaE_c -0.203204149116598
# m:2.42637465704669
# c:2.73265415098219
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0387183944796539
# deltaE_c -0.0967959861991345
# m:2.43024649649465
# c:2.74233374960210
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.000288988499336895
# deltaE_c 0.000481647498895121
# m:2.43021759764472
# c:2.74228558485221
# Iteration : 12
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0343341791237683
# deltaE_c -0.171670895618842
# m:2.43365101555710
# c:2.75945267441410
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0268347677452250
# deltaE_c -0.0670869193630623
# m:2.43633449233162
# c:2.76616136635040
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0167772370496255
# deltaE_c 0.0279620617493759
# m:2.43465676862666
# c:2.76336516017547
# Iteration : 13
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0299406972198403
# deltaE_c -0.149703486099201
# m:2.43765083834864
# c:2.77833550878539
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0186416623500627
# deltaE_c -0.0466041558751566
# m:2.43951500458365
# c:2.78299592437290
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0280229562738543
# deltaE_c 0.0467049271230904
# m:2.43671270895626
# c:2.77832543166059
# Iteration : 14
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0268664053096307
# deltaE_c -0.134332026548154
# m:2.43939934948722
# c:2.79175863431541
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0129926503558804
# deltaE_c -0.0324816258897007
# m:2.44069861452281
# c:2.79500679690438
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0356555793708400
# deltaE_c 0.0594259656180665
# m:2.43713305658573
# c:2.78906420034257
# Iteration : 15
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0247018376680564
# deltaE_c -0.123509188340282
# m:2.43960324035253
# c:2.80141511917660
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00909743387295436
# deltaE_c -0.0227435846823858
# m:2.44051298373983
# c:2.80368947764484
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0407983607332416
# deltaE_c 0.0679972678887362
# m:2.43643314766650
# c:2.79688975085597
# Iteration : 16
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0231647239221467
# deltaE_c -0.115823619610734
# m:2.43874962005872
# c:2.80847211281704
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00641121566378944
# deltaE_c -0.0160280391594734
# m:2.43939074162510
# c:2.81007491673299
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0442256170248267
# deltaE_c 0.0737093617080449
# m:2.43496817992262
# c:2.80270398056218
# Iteration : 17
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0220604766906590
# deltaE_c -0.110302383453295
# m:2.43717422759168
# c:2.81373421890751
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00455843602232631
# deltaE_c -0.0113960900558157
# m:2.43763007119391
# c:2.81487382791309
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0464711223776648
# deltaE_c 0.0774518706294414
# m:2.43298295895615
# c:2.80712864085015
# Iteration : 18
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0212549534717243
# deltaE_c -0.106274767358622
# m:2.43510845430332
# c:2.81775611758601
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00328020027706422
# deltaE_c -0.00820050069266065
# m:2.43543647433103
# c:2.81857616765528
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0479028313523360
# deltaE_c 0.0798380522538933
# m:2.43064619119579
# c:2.81059236242989
# Iteration : 19
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0206556798661907
# deltaE_c -0.103278399330953
# m:2.43271175918241
# c:2.82092020236298
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00239803758562074
# deltaE_c -0.00599509396405207
# m:2.43295156294097
# c:2.82151971175939
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0487743897143833
# deltaE_c 0.0812906495239725
# m:2.42807412396954
# c:2.81339064680699
# Iteration : 20
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0201989056798203
# deltaE_c -0.100994528399101
# m:2.43009401453752
# c:2.82349009964690
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00178891781523638
# deltaE_c -0.00447229453809106
# m:2.43027290631904
# c:2.82393732910071
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0492606437352814
# deltaE_c 0.0821010728921356
# m:2.42534684194551
# c:2.81572722181150
# Iteration : 21
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0198406819598800
# deltaE_c -0.0992034097993999
# m:2.42733091014150
# c:2.82564756279144
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00136802926078472
# deltaE_c -0.00342007315196202
# m:2.42746771306758
# c:2.82598957010663
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0494821187683088
# deltaE_c 0.0824701979471811
# m:2.42251950119075
# c:2.81774255031192
# Iteration : 22
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195507098899869
# deltaE_c -0.0977535494499344
# m:2.42447457217975
# c:2.82751790525691
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00107690634847679
# deltaE_c -0.00269226587119187
# m:2.42458226281460
# c:2.82778713184403
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0495218937196711
# deltaE_c 0.0825364895327851
# m:2.41963007344263
# c:2.81953348289075
# Iteration : 23
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0193081004841450
# deltaE_c -0.0965405024207246
# m:2.42156088349104
# c:2.82918753313282
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000875245388304302
# deltaE_c -0.00218811347076064
# m:2.42164840802987
# c:2.82940634447990
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0494372335786930
# deltaE_c 0.0823953892978215
# m:2.41670468467200
# c:2.82116680555012
# Iteration : 24
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0190984515030966
# deltaE_c -0.0954922575154833
# m:2.41861452982231
# c:2.83071603130166
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000735262707764139
# deltaE_c -0.00183815676941013
# m:2.41868805609309
# c:2.83089984697861
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0492676083806751
# deltaE_c 0.0821126806344585
# m:2.41376129525502
# c:2.82268857891516
# Iteration : 25
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0189118324067672
# deltaE_c -0.0945591620338360
# m:2.41565247849570
# c:2.83214449511854
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000637805393270963
# deltaE_c -0.00159451348317718
# m:2.41571625903503
# c:2.83230394646686
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0490402211327261
# deltaE_c 0.0817337018878765
# m:2.41081223692175
# c:2.82413057627807
# Iteration : 26
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0187413952675153
# deltaE_c -0.0937069763375762
# m:2.41268637644850
# c:2.83350127391183
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000569670203506956
# deltaE_c -0.00142417550876717
# m:2.41274334346886
# c:2.83364369146271
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0487738185264126
# deltaE_c 0.0812896975440207
# m:2.40786596161621
# c:2.82551472170831
# Iteration : 27
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0185824171936904
# deltaE_c -0.0929120859684516
# m:2.40972420333558
# c:2.83480593030515
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000521755344246255
# deltaE_c -0.00130438836061586
# m:2.40977637887001
# c:2.83493636914121
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0484813178779300
# deltaE_c 0.0808021964632166
# m:2.40492824708221
# c:2.82685614949489
# Iteration : 28
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0184316402177334
# deltaE_c -0.0921582010886666
# m:2.40677141110399
# c:2.83607196960376
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000487786381858868
# deltaE_c -0.00121946595464717
# m:2.40682018974217
# c:2.83619391619922
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0481716180267155
# deltaE_c 0.0802860300445261
# m:2.40200302793950
# c:2.82816531319477
# Iteration : 29
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0182868162434660
# deltaE_c -0.0914340812173298
# m:2.40383170956385
# c:2.83730872131650
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000463437943182932
# deltaE_c -0.00115859485795733
# m:2.40387805335817
# c:2.83742458080230
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0478508476903188
# deltaE_c 0.0797514128171981
# m:2.39909296858914
# c:2.82944943952058
# Iteration : 30
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0181463933523188
# deltaE_c -0.0907319667615942
# m:2.40090760792437
# c:2.83852263619674
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000445728253406052
# deltaE_c -0.00111432063351513
# m:2.40095218074971
# c:2.83863406826009
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0475232260259482
# deltaE_c 0.0792053767099139
# m:2.39619985814711
# c:2.83071353058910
# Iteration : 31
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0180092995562959
# deltaE_c -0.0900464977814797
# m:2.39800078810274
# c:2.83971818036725
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000432601756662709
# deltaE_c -0.00108150439165655
# m:2.39804404827841
# c:2.83982633080641
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0471916558640739
# deltaE_c 0.0786527597734565
# m:2.39332488269200
# c:2.83196105482907
# Iteration : 32
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0178747937265068
# deltaE_c -0.0893739686325339
# m:2.39511236206465
# c:2.84089845169232
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000422641392727963
# deltaE_c -0.00105660348181980
# m:2.39515462620392
# c:2.84100411204050
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0468581326577135
# deltaE_c 0.0780968877628556
# m:2.39046881293815
# c:2.83319442326422
# Iteration : 33
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0177423628296308
# deltaE_c -0.0887118141481538
# m:2.39224304922112
# c:2.84206560467903
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000414870253008903
# deltaE_c -0.00103717563252248
# m:2.39228453624642
# c:2.84216932224228
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0465240263940800
# deltaE_c 0.0775400439901333
# m:2.38763213360701
# c:2.83441531784327
# Iteration : 34
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0176116510870657
# deltaE_c -0.0880582554353286
# m:2.38939329871572
# c:2.84322114338680
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000408614850764488
# deltaE_c -0.00102153712691111
# m:2.38943416020079
# c:2.84332329709949
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0461902759319810
# deltaE_c 0.0769837932199682
# m:2.38481513260759
# c:2.83562491777750
# Iteration : 35
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0174824111401970
# deltaE_c -0.0874120557009848
# m:2.38656337372161
# c:2.84436612334759
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000403410865503773
# deltaE_c -0.00100852716375943
# m:2.38660371480816
# c:2.84446697606397
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0458575229693210
# deltaE_c 0.0764292049488686
# m:2.38201796251123
# c:2.83682405556908
# Iteration : 36
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0173544703857339
# deltaE_c -0.0867723519286696
# m:2.38375340954981
# c:2.84550129076195
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000398938167250673
# deltaE_c -0.000997345418126905
# m:2.38379330336653
# c:2.84560102530376
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0455262043942093
# deltaE_c 0.0758770073236823
# m:2.37924068292711
# c:2.83801332457140
# Iteration : 37
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0172277077686365
# deltaE_c -0.0861385388431821
# m:2.38096345370397
# c:2.84662717845571
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000394976025078764
# deltaE_c -0.000987440062696798
# m:2.38100295130648
# c:2.84672592246198
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0451966159475230
# deltaE_c 0.0753276932458720
# m:2.37648328971173
# c:2.83919315313740
# Iteration : 38
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0171020377840515
# deltaE_c -0.0855101889202574
# m:2.37819349349013
# c:2.84774417202942
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000391372229809450
# deltaE_c -0.000978430574523514
# m:2.37823263071311
# c:2.84784201508688
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0448689561088464
# deltaE_c 0.0747815935147438
# m:2.37374573510223
# c:2.84036385573540
# Iteration : 39
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0169773994488306
# deltaE_c -0.0848869972441531
# m:2.37544347504711
# c:2.84885255545982
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000388021808535477
# deltaE_c -0.000970054521338692
# m:2.37548227722797
# c:2.84894956091195
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0445433563492377
# deltaE_c 0.0742389272487296
# m:2.37102794159304
# c:2.84152566818708
# Iteration : 40
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0168537486988629
# deltaE_c -0.0842687434943143
# m:2.37271331646293
# c:2.84995254253651
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000384852351327680
# deltaE_c -0.000962130878319201
# m:2.37275180169806
# c:2.85004875562434
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0442199019859069
# deltaE_c 0.0736998366431783
# m:2.36832981149947
# c:2.84267877196002
# Iteration : 41
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0167310531480166
# deltaE_c -0.0836552657400826
# m:2.37000291681427
# c:2.85104429853403
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000381813896103811
# deltaE_c -0.000954534740259305
# m:2.37004109820388
# c:2.85113975200806
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0438986465582327
# deltaE_c 0.0731644109303877
# m:2.36565123354806
# c:2.84382331091502
# Iteration : 42
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0166092884750739
# deltaE_c -0.0830464423753696
# m:2.36731216239557
# c:2.85212795515256
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000378871955686977
# deltaE_c -0.000947179889217331
# m:2.36735004959114
# c:2.85222267314148
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0435796217376958
# deltaE_c 0.0726327028961595
# m:2.36299208741737
# c:2.84495940285186
# Iteration : 43
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0164884359329330
# deltaE_c -0.0824421796646653
# m:2.36464093101066
# c:2.85320362081833
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000376002710963164
# deltaE_c -0.000940006777407909
# m:2.36467853128176
# c:2.85329762149607
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0432628441590737
# deltaE_c 0.0721047402651225
# m:2.36035224686585
# c:2.84608714746956
# Iteration : 44
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0163684806314549
# deltaE_c -0.0818424031572742
# m:2.36198909492900
# c:2.85427138778528
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000373189697247422
# deltaE_c -0.000932974243118334
# m:2.36202641389872
# c:2.85436468520960
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0429483201292959
# deltaE_c 0.0715805335488264
# m:2.35773158188579
# c:2.84720663185471
# Iteration : 45
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0162494103536258
# deltaE_c -0.0812470517681292
# m:2.35935652292115
# c:2.85533133703153
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000370421520005326
# deltaE_c -0.000926053800013094
# m:2.35939356507315
# c:2.85542394241153
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0426360488732511
# deltaE_c 0.0710600814554185
# m:2.35512996018583
# c:2.84831793426598
# Iteration : 46
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0161312147393698
# deltaE_c -0.0806560736968494
# m:2.35674308165977
# c:2.85638354163567
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000367690280169475
# deltaE_c -0.000919225700423798
# m:2.35677985068778
# c:2.85647546420571
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0423260247710289
# deltaE_c 0.0705433746183814
# m:2.35254724821068
# c:2.84942112674387
# Iteration : 47
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0160138847227981
# deltaE_c -0.0800694236139901
# m:2.35414863668296
# c:2.85742806910527
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000364990488617156
# deltaE_c -0.000912476221543113
# m:2.35418513573182
# c:2.85751931672743
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0420182388999115
# deltaE_c 0.0700303981665193
# m:2.34998331184183
# c:2.85051627691078
# Iteration : 48
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0158974121441717
# deltaE_c -0.0794870607208584
# m:2.35157305305625
# c:2.85846498298286
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000362318317855825
# deltaE_c -0.000905795794639452
# m:2.35160928488803
# c:2.85855556256233
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0417126800970866
# deltaE_c 0.0695211334951447
# m:2.34743801687832
# c:2.85160344921281
# Iteration : 49
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0157817894823048
# deltaE_c -0.0789089474115241
# m:2.34901619582655
# c:2.85949434395396
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000359671086165747
# deltaE_c -0.000899177715414368
# m:2.34905216293517
# c:2.85958426172551
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0414093356919647
# deltaE_c 0.0690155594866075
# m:2.34491122936597
# c:2.85268270577684
# Iteration : 50
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0156670096699922
# deltaE_c -0.0783350483499610
# m:2.34647793033297
# c:2.86051621061184
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.000357046901988012
# deltaE_c -0.000892617254970141
# m:2.34651363502317
# c:2.86060547233734
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0411081920107441
# deltaE_c 0.0685136533512400
# m:2.34240281582210
# c:2.85375410700221
# ++++++++++++++++++++++++++++++++++++++
# Optimal Values:
# m:2.34240281582210
# c:2.85375410700221

# %%
#y =1.77x+0.99 --> BestFit Line
y_train_pred=[]
for i in range(0,len(x_train)):
  y_cal = mi*x_train['bacteria_size'][i]+ci
  y_train_pred.append(y_cal)
y_train_pred
# Out:
# [3.32223467016663, 3.79071523333105, 4.25919579649547]

# %%
y_train_list = list(y_train['max_growth'])
y_train_list
# Out:
# [3.4, 3.8, 4.2]

# %%
x_train_list=list(x_train['bacteria_size'])
x_train_list
# Out:
# [0.2, 0.4, 0.6]

# %%
Error=[]
for i in range(0,len(x_train)):
  err=(y_train_list[i]-y_train_pred[i])
  Error.append(err)
Error
# Out:
# [0.0777653298333671, 0.00928476666894751, -0.0591957964954712]

# %%
import matplotlib.pyplot as plt
plt.plot(x_train_list,y_train_list,label='y_train',color='green')
plt.plot(x_train_list,y_train_pred,label='y_predicted',color='red')

plt.title('Visualising the Training Error')
plt.xlabel('x values')
plt.ylabel('y values')

plt.show()
